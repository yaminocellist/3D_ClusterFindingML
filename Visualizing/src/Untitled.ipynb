# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../csv/event74_hits.csv")

# %%
data
# Out:
#         event  layer       phi  tbin  adc  zelem        x        y        z  \
# 0          74      3 -0.399423  -8.0  210      0  7.09161 -2.99346 -7.77245
# 1          74      3  0.806673  40.0   45      0  5.04564  5.26504 -9.37245
# 2          74      3  0.807742  40.0   45      0  5.04013  5.27055 -9.37245
# 3          74      3  0.649190  82.0  120      0  5.86202  4.44885 -4.57245
# 4          74      3  0.649190  82.0   90      0  5.86202  4.44885 -2.97245
# ...       ...    ...       ...   ...  ...    ...      ...      ...      ...
# 431635     74     56       NaN   NaN  374   -666      NaN      NaN      NaN
# 431636     74     56       NaN   NaN  171   -666      NaN      NaN      NaN
# 431637     74     56       NaN   NaN  158   -666      NaN      NaN      NaN
# 431638     74     56       NaN   NaN  153   -666      NaN      NaN      NaN
# 431639     74     56       NaN   NaN  241   -666      NaN      NaN      NaN
#
#         plot_x   plot_y   plot_z
# 0         -8.0  2.76386 -1.16666
# 1         40.0  2.07571  2.16597
# 2         40.0  2.07340  2.16819
# 3         82.0  2.38972  1.81362
# 4         82.0  2.38972  1.81362
# ...        ...      ...      ...
# 431635     NaN      NaN      NaN
# 431636     NaN      NaN      NaN
# 431637     NaN      NaN      NaN
# 431638     NaN      NaN      NaN
# 431639     NaN      NaN      NaN
#
# [431640 rows x 12 columns]

# %%
from matplotlib import colormaps
from matplotlib.colors import LinearSegmentedColormap, PowerNorm
BASE_CMAP = colormaps.get_cmap("viridis")
BLUE_TO_YELLOW = LinearSegmentedColormap.from_list(
    "viridis_blue_yellow",
    BASE_CMAP(np.linspace(0.25, 1.0, 256)),
)

fig = plt.figure(figsize=(11, 8))
ax = fig.add_subplot(111, projection="3d")

ax.scatter(
    data.x,
    data.y,
    data.z,
    c=data.adc,
    cmap=BLUE_TO_YELLOW,
    # norm=norm,
    s=1.2,
    linewidths=0,
    rasterized=True,
)
